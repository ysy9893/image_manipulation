# %%
import os 
import cv2

# %%
LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/car/Label'
IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/car/Image'
NEW_LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/car/new_Label'
NEW_IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/car/new_Image'

label_list=os.listdir(LABEL_PATH)
i=0
for file in label_list:
    i+=1
    image=file.replace('.txt','.jpg')
    print(image)
    box=[]
    f=open(LABEL_PATH+'/'+file,'r')
    
    while 1:
        
        line=f.readline()
        if not line:
            break

        box.append(line.split())
    f.close()

    
    
    
    image=cv2.imread(IMAGE_PATH+'/'+image)
    imH,imW=image.shape[:2]
    
    
    
    f=open(NEW_LABEL_PATH+'/'+'car'+str(i)+'.txt','w')
    
    for b in box:
        pick=[float(i) for i in b if i!='Car']
        print(pick)
        #x1,y1,x2,y2=convert(imH,imW,pick)
        
        #text="0"+" "+str(x1)+" "+str(y1)+" "+str(x2)+" "+str(y2)
        text="1"+" "+str(pick[0])+" "+str(pick[1])+" "+str(pick[2])+" "+str(pick[3])
        f.write(text+'\n')
    f.close()
    
    
    cv2.imwrite(NEW_IMAGE_PATH+'/car'+str(i)+'.jpg',image)
# Out:
# 001272829ec1711e.jpg
# [0.0, 282.879744, 72.32, 323.840256]
# [0.0, 266.88, 626.56, 576.639744]
# [580.48, 285.44025600000003, 691.2, 322.56]
# [765.44, 261.759744, 784.0, 276.48]
# 0015007e4c8d174b.jpg
# [0.0, 494.079744, 42.88, 525.440256]
# [940.8, 501.75974400000007, 971.52, 537.5999999999999]
# [955.52, 505.599744, 1016.32, 552.320256]
# 001e7cd628da5b6c.jpg
# [0.0, 255.997279, 236.544, 440.315074]
# [13.312, 176.12589300000002, 591.872, 507.897924]
# [456.704, 225.27730499999998, 1004.544, 605.176931]
# [959.488, 335.86798200000004, 977.92, 404.475332]
# 0021b788b5bd4b47.jpg
# [36.48, 200.54314300000001, 57.6, 235.782528]
# [51.2, 208.231674, 68.48, 226.812689]
# [67.2, 181.96281100000002, 140.16, 239.626452]
# [120.96, 37.802001, 904.32, 630.461591]
# [174.72, 199.261835, 191.36, 231.93792100000002]
# [224.64, 169.789019, 292.48, 237.063836]
# [373.76, 187.08804300000003, 417.28, 213.35758900000002]
# [405.12, 187.08804300000003, 438.4, 206.950366]
# 002a78dc4331b2a6.jpg
# ...

# %%
def convert(imH,imW,pick):
    x=pick[1]*imW
    y=pick[2]*imH
    w=pick[3]*imW
    h=pick[4]*imH
    
    w_half=w*0.5
    h_half=h*0.5
    
    x1=x-w_half
    y1=y-h_half
    x2=x+w_half
    y2=y+h_half
    
    return x1,y1,x2,y2
