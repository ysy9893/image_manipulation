# %%
import os 
import cv2

# %%
LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/human/Label'
IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/human/Image'
NEW_LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/human/new_Label'
NEW_IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/human/new_Image'

label_list=os.listdir(LABEL_PATH)
i=0
for file in label_list:
    i+=1
    image=file.replace('.txt','.jpg')
    print(image)
    box=[]
    f=open(LABEL_PATH+'/'+file,'r')
    
    while 1:
        
        line=f.readline()
        if not line:
            break

        box.append(line.split())
    f.close()

    
    
    
    image=cv2.imread(IMAGE_PATH+'/'+image)
    imH,imW=image.shape[:2]
    
    
    
    f=open(NEW_LABEL_PATH+'/'+'human'+str(i)+'.txt','w')
    
    for b in box:
        pick=[float(i) for i in b if (i!='Human'and i!='face'and i!='body')]
        print(pick)
        x1,y1,x2,y2=convert(imH,imW,pick)
        
        text="0"+" "+str(x1)+" "+str(y1)+" "+str(x2)+" "+str(y2)
        #text="2"+" "+str(pick[0])+" "+str(pick[1])+" "+str(pick[2])+" "+str(pick[3])
        f.write(text+'\n')
    f.close()
    
    
    cv2.imwrite(NEW_IMAGE_PATH+'/human'+str(i)+'.jpg',image)
# Out:
# 000444a1be4878f3.jpg
# [0.0, 252.087577, 161.614848, 678.345444]
# [117.122048, 280.242991, 191.058944, 578.165105]
# [252.56448, 204.943928, 590.190592, 678.345444]
# [435.11808, 212.801316, 714.510336, 678.345444]
# [662.16448, 297.266879, 756.385792, 515.30668]
# [712.547328, 201.015234, 959.222784, 678.345444]
# 0009b55a07465460.jpg
# [734.72, 143.92443899999998, 867.84, 632.6287590000001]
# 002db8012f87a91a.jpg
# [809.632768, 1.77072, 1021.34272, 330.26036]
# 003d2f57ede24ec6.jpg
# [2.56, 159.339216, 227.84, 605.3600640000001]
# [737.28, 92.147754, 964.48, 605.3600640000001]
# 004570a9c185f956.jpg
# [110.00962999999999, 66.56, 572.43258, 766.08]
# 004eb1fb1f76355b.jpg
# [305.92, 1.92, 814.08, 1023.36]
# [472.96, 254.72, 838.4, 1022.72]
# 005fd6fbae2a8427.jpg
# [101.999616, 110.999808, 241.000448, 307.00032]
# [700.000256, 227.00006399999998, 849.999872, 374.99980800000003]
# 006845a2df67a416.jpg
# [327.68, 151.053124, 892.8, 789.829444]
# 006a1bb8403536e4.jpg
# ...

# %%
def convert(imH,imW,pick):
    x=pick[1]*imW
    y=pick[2]*imH
    w=pick[3]*imW
    h=pick[4]*imH
    
    w_half=w*0.5
    h_half=h*0.5
    
    x1=x-w_half
    y1=y-h_half
    x2=x+w_half
    y2=y+h_half
    
    return x1,y1,x2,y2
