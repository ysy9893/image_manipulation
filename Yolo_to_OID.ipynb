# %%
import os 
import cv2

# %%
LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/Label'
IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/Image'
NEW_LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/new_Label'
NEW_IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/new_Image'

label_list=os.listdir(LABEL_PATH)
i=0
for file in label_list:
    i+=1
    image=file.replace('.txt','.jpg')
    print(image)
    box=[]
    f=open(LABEL_PATH+'/'+file,'r')
    
    while 1:
        
        line=f.readline()
        if not line:
            break

        box.append(line.split())
    f.close()

    
    
    
    image=cv2.imread(IMAGE_PATH+'/'+image)
    imH,imW=image.shape[:2]
    
    
    
    f=open(NEW_LABEL_PATH+'/'+'mask'+str(i)+'.txt','w')
    
    for b in box:
        pick=[float(b[i]) for i in range(1,len(b))]
        x1,y1,x2,y2=convert(imH,imW,pick)
        
        text="mask"+" "+str(x1)+" "+str(y1)+" "+str(x2)+" "+str(y2)
        #text="mask"+" "+str(pick[0])+" "+str(pick[1])+" "+str(pick[2])+" "+str(pick[3])
        f.write(text+'\n')
    f.close()
    
    
    cv2.imwrite(NEW_IMAGE_PATH+'/mask'+str(i)+'.jpg',image)
# Out:
# -1x-1_jpg.rf.69d9b61e3cdb8a9047dad25099fcc8ef.jpg
# -I1-MS09uaqsLdGTFkgnS0Rcg1mmPyAj95ySg_eckoM_jpeg.rf.b60002517c9371bba207314a49452cf1.jpg
# 0002526673_jpg.rf.a13de6faa0e2e5250d913ccf27b4c769.jpg
# 0009S6815V3PEU1N-C123-F4_jpg.rf.128ad940f96aa8fa5174093ddb7ae5ee.jpg
# 000b7b75-1600_jpg.rf.35b739ea6899972b07aab7225d341307.jpg
# 000_1OC3DT_jpg.rf.3d1fb8e38f21ec81247c6c3850038888.jpg
# 000_1ov3n5_0_jpeg.rf.edad89426b118f4c76ba4ae3790b3f31.jpg
# 001_1024_jpeg.rf.82de51e9c6db87b2941a34e6c65de14a.jpg
# 002_1024_jpeg.rf.21167ff8a675d17c91a8c57a5269dad7.jpg
# 003_1024_jpeg.rf.3d3235de8495eb432dc3c54d17287980.jpg
# 004_1024_jpeg.rf.8387cade019b2c139de783457af677ae.jpg
# 0109-00176-096b1_jpg.rf.69ffdcd78617808a849bb59feea2afca.jpg
# 012106_jpg_1140x855_jpg.rf.b2002b96c6972613f93d98f69f0efdee.jpg
# 012420_coronoa_masks_web_jpg.rf.aa87c46891116535f04447105006c814.jpg
# 0200b38c89b16c37c5de8e247bb00c2f_jpg.rf.4868c78878c91c2c7cc7062e90de7658.jpg
# ...

# %%
def convert(imH,imW,pick):
    x=pick[0]*imW
    y=pick[1]*imH
    w=pick[2]*imW
    h=pick[3]*imH
    
    w_half=w*0.5
    h_half=h*0.5
    
    x1=x-w_half
    y1=y-h_half
    x2=x+w_half
    y2=y+h_half
    
    return x1,y1,x2,y2
