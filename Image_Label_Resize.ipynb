# %%
import os 
import cv2

# %%
IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/new_Image'
LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/new_Label'
RESIZED_IMAGE_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/resized_Image'
RESIZED_LABEL_PATH='C:/Users/gptjd/OneDrive/Desktop/tflite_data/mask/resized_Label'

image_list=os.listdir(IMAGE_PATH)

for image in image_list:
    if image=="desktop.ini":
        continue
    name=image
    image=cv2.imread(IMAGE_PATH+'/'+image)
    print("image.shape={0}".format(image.shape))
    
    imH,imW=image.shape[:2]
    
    image=cv2.resize(image,(300,300))
    print("new_image.shape={0}".format(image.shape))
    
    cv2.imwrite(RESIZED_IMAGE_PATH+'/'+name,image)
    
    
    label=name.replace('.jpg','.txt')
    
    f=open(LABEL_PATH+'/'+label,'r')
    
    box=[]
    while 1:
        
        line=f.readline()
        if not line:
            break
        box.append(line.split())
    f.close()
    
    f=open(RESIZED_LABEL_PATH+'/'+label,'w')
    
    for b in box:
        pick=[float(b[i]) for i in range(1,len(b))]
        
        x1=pick[0]*(300.0/imW)
        y1=pick[1]*(300.0/imH)
        x2=pick[2]*(300.0/imW)
        y2=pick[3]*(300.0/imH)
        
        text='mask'+" "+str(x1)+" "+str(y1)+" "+str(x2)+" "+str(y2)
        f.write(text+"\n")
    f.close()
# Out:
# image.shape=(1363, 2000, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(576, 1024, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(925, 1440, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(552, 937, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(2861, 4291, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(900, 1600, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(814, 1200, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(853, 1280, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(675, 1200, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(720, 1280, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(768, 768, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(340, 512, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(576, 1024, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(853, 1280, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(770, 1024, 3)
# new_image.shape=(300, 300, 3)
# image.shape=(1200, 1800, 3)
# new_image.shape=(300, 300, 3)
# ...
